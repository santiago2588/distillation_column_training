# %% [markdown]
# <a href="https://colab.research.google.com/github/santiago2588/distillation_column_training/blob/main/02_feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/santiago2588/distillation_column_training/main/data/clean_data.csv -O clean_data.csv
# Out:
# --2025-07-07 13:36:22--  https://raw.githubusercontent.com/santiago2588/distillation_column_training/main/data/clean_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52380 (51K) [text/plain]
# Saving to: ‘clean_data.csv’
#
# clean_data.csv      100%[===================>]  51.15K  --.-KB/s    in 0.01s
#
# 2025-07-07 13:36:22 (4.14 MB/s) - ‘clean_data.csv’ saved [52380/52380]

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("clean_data.csv")

# Display the first few rows to confirm it loaded correctly
df.head()
# Out:
#       Temp1    FlowC1     Temp2    TempC1     Temp3    TempC2    TempC3  \
# 0  139.9857  432.0636  377.8119  100.2204  492.1353  490.1459  180.5578
# 1  131.0470  487.4029  371.3060  100.2297  482.2100  480.3128  172.6575
# 2  118.2666  437.3516  378.4483  100.3084  488.7266  487.0040  165.9400
# 3  118.1769  481.8314  378.0028   95.5766  493.1481  491.1137  167.2085
# 4  120.7891  412.6471  377.8871   92.9052  490.2486  488.6641  167.0326
#
#       Temp4  PressureC1     Temp5  ...   TempC9   FlowC2     Temp9    Temp10  \
# 0  187.4331    215.0627  489.0043  ...  86.6133  69.9017  461.2371  513.9653
# 1  179.5089    205.0999  479.0443  ...  97.6100  69.6900  450.3000  504.5145
# 2  172.9262    205.0304  485.1326  ...  88.4967  70.5867  458.8101  508.9997
# 3  174.2338    205.2561  490.4338  ...  95.3483  70.2167  462.5252  514.1794
# 4  173.9681    205.0883  486.1049  ...  82.9533  69.6567  460.7509  511.0948
#
#    FlowC3   FlowC4   Temp11    Temp12  VapourPressure      Yield
# 0  8.6279  10.5988  30.8983  489.9900         32.5026  69.400623
# 1  8.7662  10.7560  31.9099  480.2888         34.8598  66.532666
# 2  8.5319  10.5737  29.9165  486.6190         32.1666  71.102193
# 3  8.6260  10.6695  30.6229  491.1304         30.4064  69.793481
# 4  8.5939  10.4922  29.4977  487.6475         30.9238  71.489516
#
# [5 rows x 24 columns]

# %%
#Add a random uniform column from Yield
# Step 1: Get the range of the column
min_value = df['Yield'].min()
max_value = df['Yield'].max()

# Step 2: Generate random uniform values within the range
random_uniform_values = np.random.uniform(min_value, max_value, size=len(df))

# Step 3: Add the random uniform column to the DataFrame
df['RandomUniform'] = random_uniform_values

# Display the updated DataFrame
df
# Out:
#         Temp1    FlowC1     Temp2    TempC1     Temp3    TempC2    TempC3  \
# 0    139.9857  432.0636  377.8119  100.2204  492.1353  490.1459  180.5578
# 1    131.0470  487.4029  371.3060  100.2297  482.2100  480.3128  172.6575
# 2    118.2666  437.3516  378.4483  100.3084  488.7266  487.0040  165.9400
# 3    118.1769  481.8314  378.0028   95.5766  493.1481  491.1137  167.2085
# 4    120.7891  412.6471  377.8871   92.9052  490.2486  488.6641  167.0326
# ..        ...       ...       ...       ...       ...       ...       ...
# 248  130.8138  212.6385  341.5964  121.4354  468.3401  467.0299  174.7639
# 249  128.9673  225.1412  349.8965  118.8604  479.7665  478.4652  176.2176
# 250  130.5328  223.5965  345.9366  120.4027  474.5378  473.1145  176.3310
# 251  128.5248  213.5613  343.4950  119.6989  469.3802  467.9954  174.6435
# 252  131.0491  217.4117  346.1960  119.0825  474.6599  473.0381  177.1088
#
#         Temp4  PressureC1     Temp5  ...   FlowC2     Temp9    Temp10  FlowC3  \
# 0    187.4331    215.0627  489.0043  ...  69.9017  461.2371  513.9653  8.6279
# 1    179.5089    205.0999  479.0443  ...  69.6900  450.3000  504.5145  8.7662
# 2    172.9262    205.0304  485.1326  ...  70.5867  458.8101  508.9997  8.5319
# 3    174.2338    205.2561  490.4338  ...  70.2167  462.5252  514.1794  8.6260
# 4    173.9681    205.0883  486.1049  ...  69.6567  460.7509  511.0948  8.5939
# ..        ...         ...       ...  ...      ...       ...       ...     ...
# 248  180.7649    229.7393  465.4282  ...  72.2767  451.9269  479.0290  5.5590
# 249  182.3646    230.5049  477.2564  ...  72.1567  462.5281  491.2362  5.6342
# 250  182.2578    230.6638  471.4597  ...  72.5500  457.5511  485.8786  5.4810
# 251  180.5093    230.5226  466.4124  ...  72.2250  452.7025  480.2879  5.4727
# 252  183.1810    225.6420  471.3944  ...  72.3600  457.7832  486.0253  5.4597
#
#       FlowC4   Temp11    Temp12  VapourPressure      Yield  RandomUniform
# 0    10.5988  30.8983  489.9900         32.5026  69.400623      66.573373
# 1    10.7560  31.9099  480.2888         34.8598  66.532666      66.605180
# 2    10.5737  29.9165  486.6190         32.1666  71.102193      67.870101
# 3    10.6695  30.6229  491.1304         30.4064  69.793481      72.197927
# 4    10.4922  29.4977  487.6475         30.9238  71.489516      65.429283
# ..       ...      ...       ...             ...        ...            ...
# 248   6.4470  16.4131  466.3347         38.8507  69.037071      69.569542
# 249   6.4360  17.2385  477.8816         34.2653  69.202425      68.952635
# 250   6.3575  16.9866  472.3176         36.5717  69.409546      70.570719
# 251   6.4175  16.6778  467.0001         38.1054  69.072711      69.615556
# 252   6.3291  16.8766  472.2701         35.6298  68.128288      70.501162
#
# [253 rows x 25 columns]

# %%
# Feature importance using Random Forest
from sklearn.ensemble import RandomForestRegressor

X = df.drop(columns=['Yield'])  # Features
y = df['Yield']  # Target

model = RandomForestRegressor(random_state=42)
model.fit(X, y)

# Plot feature importance
importances = model.feature_importances_
feature_names = X.columns
sorted_indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 6))
plt.bar(range(X.shape[1]), importances[sorted_indices], align="center")
plt.xticks(range(X.shape[1]), feature_names[sorted_indices], rotation=90)
plt.title("Feature Importance")
plt.show()

# %%
# Create a DataFrame to store feature names and their importances
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
})

# Identify features to drop (importance < random uniform value)
# Extract the importance of the RandomUniform column
random_uniform_importance = importance_df[importance_df['Feature'] == 'RandomUniform']['Importance'].values[0]

# Identify features with importance less than the RandomUniform importance
features_to_drop = importance_df[importance_df['Importance'] < random_uniform_importance]['Feature'].tolist()
features_to_drop
# Out:
# ['Temp2',
#  'TempC1',
#  'Temp3',
#  'TempC2',
#  'TempC3',
#  'Temp4',
#  'PressureC1',
#  'Temp5',
#  'Temp6',
#  'OC1',
#  'Temp7',
#  'Temp8',
#  'FlowC2',
#  'Temp9',
#  'Temp10',
#  'FlowC3',
#  'FlowC4',
#  'Temp11',
#  'Temp12',
#  'VapourPressure']

# %%
# Step 5: Drop the low-importance features
df_reduced = df.drop(columns=features_to_drop)
df_reduced.drop(columns=['RandomUniform'], inplace=True)
df_reduced
# Out:
#         Temp1    FlowC1   TempC9      Yield
# 0    139.9857  432.0636  86.6133  69.400623
# 1    131.0470  487.4029  97.6100  66.532666
# 2    118.2666  437.3516  88.4967  71.102193
# 3    118.1769  481.8314  95.3483  69.793481
# 4    120.7891  412.6471  82.9533  71.489516
# ..        ...       ...      ...        ...
# 248  130.8138  212.6385  41.9133  69.037071
# 249  128.9673  225.1412  45.6567  69.202425
# 250  130.5328  223.5965  44.8278  69.409546
# 251  128.5248  213.5613  41.7078  69.072711
# 252  131.0491  217.4117  43.5767  68.128288
#
# [253 rows x 4 columns]

# %%
# Calculate correlation matrix
corr_matrix = df_reduced.corr()

# Create the heatmap
fig = px.imshow(
    corr_matrix,  # Correlation matrix
    text_auto=True,  # Automatically add correlation values as text
    color_continuous_scale='RdBu',  # Red-Blue color scale
    zmin=-1,  # Minimum value for the color scale
    zmax=1  # Maximum value for the color scale
)

# Customize the layout
fig.update_layout(
    title='Correlation Matrix',
    xaxis_title='Features',
    yaxis_title='Features',
    width=800,  # Adjust width
    height=800  # Adjust height
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9d756448-5e38-4f6a-887f-e0133566d07a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d756448-5e38-4f6a-887f-e0133566d07a")) {                    Plotly.newPlot(                        "9d756448-5e38-4f6a-887f-e0133566d07a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Temp1","FlowC1","TempC9","Yield"],"y":["Temp1","FlowC1","TempC9","Yield"],"z":[[1.0,0.017277133374479885,0.01157657146165051,-0.29664306632789583],[0.017277133374479885,1.0,0.9974597456821341,0.2785432796701152],[0.01157657146165051,0.9974597456821341,1.0,0.28000372349915925],[-0.29664306632789583,0.2785432796701152,0.28000372349915925,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line" ...

# %%
# Set the correlation threshold
threshold = 0.9

# Create a set to store features to remove
features_to_remove = set()

# Iterate through the correlation matrix
for col in corr_matrix.columns:
    for row in corr_matrix.index:
        # Check if the correlation is above the threshold and the features are not the same
        if (corr_matrix.loc[row, col] > threshold) and (row != col):
            # If neither feature has been marked for removal, add one of them to the removal set
            if row not in features_to_remove and col not in features_to_remove:
                features_to_remove.add(row)

print("Features to remove:", features_to_remove)
# Out:
# Features to remove: {'TempC9'}

# %%
# Drop the highly correlated features
df1 = df_reduced.drop(columns=features_to_remove)

print("DataFrame after removing highly correlated features:")
print(df1.head())
# Out:
# DataFrame after removing highly correlated features:
#       Temp1    FlowC1      Yield
# 0  139.9857  432.0636  69.400623
# 1  131.0470  487.4029  66.532666
# 2  118.2666  437.3516  71.102193
# 3  118.1769  481.8314  69.793481
# 4  120.7891  412.6471  71.489516

# %%
# Create a scatterplot matrix with smaller markers and transparency
sns.pairplot(df1, plot_kws={'s': 10, 'alpha': 0.5})
plt.suptitle('Scatterplot Matrix', y=1.02)
plt.show()

# %%
# Create the scatter plot
fig = px.scatter(
    df1,
    x='FlowC1',
    y='Temp1',
    color='Yield',  # Color by Yield
    title='Scatter Plot of Temp1 vs FlowC1 (Colored by Yield)',
    labels={'Temp1': 'Temp1', 'FlowC1': 'FlowC1', 'Yield': 'Yield'},
    color_continuous_scale='viridis',  # Color scale
    opacity=0.7  # Transparency
)

# Update marker size
fig.update_traces(marker=dict(size=10))

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a9924c0-bb97-462c-8b3c-9d1ef76f30c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a9924c0-bb97-462c-8b3c-9d1ef76f30c6")) {                    Plotly.newPlot(                        "2a9924c0-bb97-462c-8b3c-9d1ef76f30c6",                        [{"hovertemplate":"FlowC1=%{x}\u003cbr\u003eTemp1=%{y}\u003cbr\u003eYield=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[69.40062325,66.53266646,71.10219259,69.79348088,71.48951583,69.05508903,69.16105249,71.39919122,70.12587968,69.72631904,67.77787094,70.72671443,69.65671047,69.53518784,70.44829579,69.0961358,67.69307438,69.89946566,69.9737906,70.05030197,71.1950835,71.14084948,71.9782232,69.221689,69.3680077,70.16545973,70.0761285,69.29715961,71.07169554,67.1441158,65.72632849,69.20356716,69.06867956,73.24242551,68.2531281,66.74562168,70.10385691,71.86946171,67.17430263,70.475956,68.09191326,68.51335753,69.23730962,69.99149499,69.71265582,69.9002972,68.61454385,70.22958212,69.1030408,69.19803928,70.35464241,67.95517271,68.56284262,70.62892053,69.3403362,70.75360243,68.23514289,67.41768221,68.7729804,69.15184501,70.5522328,70.8399518,69.14806899,69.63127302,69.56923668,70.15347909,67.42921477,66.35177565,65.9666288,70.00787344,68.86576881,69.62978167,70.5154403,70.85871622,69.70247949,71.41347474,69.6753746,68.61725188,69.03646759,68.97093693,69.42521216,69.64686487,69.18587787,69.17112349,69.3394429,69.22643223,68.8290755,69.55523311,70.51535463,68.67003938,67.73867765,70.57274236,66.22079032,68.19356335,69.0661189,68.66998869,66.21190868,68.61413287,68.74461503,68.08453782,73.47196291,69.88996538,69.79328683,70.3673841,70.24489731,69.44064697,69.68544827,69.41747636,70.30723056,69.71065366,71.06135872,67.27233172,70.7807349,69.74341971,69.43157749,70.26063005,65.60296649,67.08823522,69.82557904,70.08965793,68.50565589,71.20794432,72.24843001,69.6805515,70.14458396,72.4788414,69.75640144,70.44273264,71.62413816,72.02252952,69.16583277,66.45684278,71.62101516,68.12410437,72.11225722,73.04342876,71.48357975,69.13398834,69.96387145,69.83507951,68.11853037,70.21541562,70.61003726,70.43304888,70.53945535,71.56382972,71.1915316,70.2946328,67.31016662,69.57651987,70.53164388,71.06860413,70.35533597,70.8762685,71.94753954,69.55021402,71.62008662,71.33576181,69.69483149,69.4793749,69.85273574,69.04912965,71.14137713,67.335228,68.81613365,67.81543121,68.27705451,68.39696047,66.16329064,65.20380122,68.91383565,69.81308354,69.14016181,68.79518716,69.34127045,69.50015922,69.25439745,69.19695798,68.3476409,70.27402365,68.96389539,66.31538497,70.09205919,70.01818121,67.08052959,67.72398688,69.44128409,69.30400436,70.44836136,67.58940328,69.46258079,68.17109062,69.52149146,70.1708357,69.22136745,70.30505441,68.00825661,67.09533024,68.29204198,69.66409538,69.98295828,69.39259405,69.89872648,69.94650715,68.25280598,68.39272203,68.4580645,69.4581878,69.47875431,69.76866048,69.13081503,69.72254947,69.67856537,68.88677448,68.78453977,68.97361904,70.0302266,69.40464826,69.61281052,68.17455228,68.68465412,70.40152209,70.07025182,69.8942037,69.22925575,69.48638901,69.73567054,68.7036476,68.9532899,68.79223279,69.33350817,68.01193362,68.40337093,69.28369237,68.15913891,68.45025312,69.36956053,68.54633474,69.32275369,69.42767879,69.44328193,67.9797013,68.80611948,69.48959862,69.1287286,69.88349268,69.79009081,69.3831685,69.03707116,69.20242478,69.40954608,69.07271059,68.12828793],"coloraxis":"coloraxis","opacity":0.7,"symbol":"circle","size":10},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[432.0636,487.4029,437.3516,481.8314,412.6471,470.8127,493.493212,429.058,414.0616,493.493212,493.493212,437.2185,457.8587,479.9308,443.2095,49 ...

# %%
# Calculate differences between columns
df1['Temp1_diff'] = df['Temp1'].diff()
df1['FlowC1_diff'] = df['FlowC1'].diff()
df1['PressureC1_diff'] = df['PressureC1'].diff()
df1['OC1_diff'] = df['OC1'].diff()
df1['Temp11_diff'] = df['Temp11'].diff()
df1
# Out:
#         Temp1    FlowC1      Yield  Temp1_diff  FlowC1_diff  PressureC1_diff  \
# 0    139.9857  432.0636  69.400623         NaN          NaN              NaN
# 1    131.0470  487.4029  66.532666     -8.9387      55.3393          -9.9628
# 2    118.2666  437.3516  71.102193    -12.7804     -50.0513          -0.0695
# 3    118.1769  481.8314  69.793481     -0.0897      44.4798           0.2257
# 4    120.7891  412.6471  71.489516      2.6122     -69.1843          -0.1678
# ..        ...       ...        ...         ...          ...              ...
# 248  130.8138  212.6385  69.037071     -0.2327     -16.4427          -0.3402
# 249  128.9673  225.1412  69.202425     -1.8465      12.5027           0.7656
# 250  130.5328  223.5965  69.409546      1.5655      -1.5447           0.1589
# 251  128.5248  213.5613  69.072711     -2.0080     -10.0352          -0.1412
# 252  131.0491  217.4117  68.128288      2.5243       3.8504          -4.8806
#
#      OC1_diff  Temp11_diff
# 0         NaN          NaN
# 1      1.6375       1.0116
# 2     -0.4483      -1.9934
# 3      0.1633       0.7064
# 4     -0.9958      -1.1252
# ..        ...          ...
# 248    0.1733      -2.5893
# 249   -0.4166       0.8254
# 250    0.1683      -0.2519
# 251    0.3083      -0.3088
# 252   -0.2716       0.1988
#
# [253 rows x 8 columns]

# %%
# Assuming df1 is already defined
X = df1.drop(columns=['Yield'])  # Features
y = df1['Yield']  # Target

# Train the model
model = RandomForestRegressor(random_state=42)
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_
feature_names = X.columns

# Create a DataFrame for Plotly Express
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

# Sort the DataFrame by importance
importance_df = importance_df.sort_values('Importance', ascending=False)

# Create the bar chart using Plotly Express
fig = px.bar(
    importance_df,
    x='Feature',
    y='Importance',
    title='Feature Importance',
    labels={'Feature': 'Features', 'Importance': 'Importance'},
    text='Importance'  # Optional: Display importance values on bars
)

# Update layout for better visualization
fig.update_layout(
    xaxis_tickangle=-90,
    template="plotly_white"
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73a505d0-68b0-4fa5-9bb4-7ab82aef6f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73a505d0-68b0-4fa5-9bb4-7ab82aef6f62")) {                    Plotly.newPlot(                        "73a505d0-68b0-4fa5-9bb4-7ab82aef6f62",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{x}\u003cbr\u003eImportance=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.30703651454484643,0.27978095179736406,0.237324250873388,0.052794570529425947,0.04914388465144904,0.03966093072315963,0.034258896880366825],"textposition":"auto","x":["PressureC1_diff","FlowC1","Temp1","Temp11_diff","FlowC1_diff","Temp1_diff","OC1_diff"],"xaxis":"x","y":[0.30703651454484643,0.27978095179736406,0.237324250873388,0.052794570529425947,0.04914388465144904,0.03966093072315963,0.034258896880366825],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"p ...

# %%
# Replace NaN with 0
df1_filled = df1.fillna(0)

# %%
df2=df1_filled[['PressureC1_diff','FlowC1','Temp1','Yield']]
df2
# Out:
#      PressureC1_diff    FlowC1     Temp1      Yield
# 0             0.0000  432.0636  139.9857  69.400623
# 1            -9.9628  487.4029  131.0470  66.532666
# 2            -0.0695  437.3516  118.2666  71.102193
# 3             0.2257  481.8314  118.1769  69.793481
# 4            -0.1678  412.6471  120.7891  71.489516
# ..               ...       ...       ...        ...
# 248          -0.3402  212.6385  130.8138  69.037071
# 249           0.7656  225.1412  128.9673  69.202425
# 250           0.1589  223.5965  130.5328  69.409546
# 251          -0.1412  213.5613  128.5248  69.072711
# 252          -4.8806  217.4117  131.0491  68.128288
#
# [253 rows x 4 columns]

# %%
df2.describe()
# Out:
#        PressureC1_diff        FlowC1         Temp1       Yield
# count     2.530000e+02  2.530000e+02  2.530000e+02  253.000000
# mean      1.404235e-17  6.178632e-16 -8.425408e-17   69.400623
# std       1.001982e+00  1.001982e+00  1.001982e+00    1.345877
# min      -5.589978e+00 -1.530986e+00 -1.552523e+00   65.203801
# 25%      -7.350971e-02 -8.865096e-01 -9.105001e-01   68.744615
# 50%      -7.811229e-03 -1.921952e-01 -1.903639e-01   69.440647
# 75%       5.973660e-02  7.464558e-01  6.795686e-01   70.125880
# max       7.117139e+00  2.224606e+00  2.663019e+00   73.471963

# %%
# Normalize or standardize features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df2.iloc[:, :-1])  # Exclude target column
df2.iloc[:, :-1] = scaled_features
df_norm=df2
df_norm.head()
# Out:
#    PressureC1_diff    FlowC1     Temp1      Yield
# 0        -0.007811  1.484445  0.634587  69.400623
# 1        -1.868888  2.151224 -0.116680  66.532666
# 2        -0.020794  1.548160 -1.190829  71.102193
# 3         0.034350  2.084094 -1.198368  69.793481
# 4        -0.039157  1.250497 -0.978822  71.489516
